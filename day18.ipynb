# %% [markdown]
# <h1>Day 18</h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print("library Imported!")
# Out:
# library Imported!

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='tip',y='total_bill',data=df)
plt.show()

# %%
sns.relplot(x='tip',y='total_bill',data=df,hue='sex')
plt.show()

# %%
sns.relplot(x='tip',y='total_bill',data=df,hue='sex',style='smoker')
plt.show()

# %%
sns.relplot(x='tip',y='total_bill',data=df,hue='sex',style='smoker',col='day')
plt.show()

# %%
sns.relplot(x='tip',y='total_bill',data=df,hue='time',col='day')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
## to ignore the warnings

# %%
sns.relplot(x='tip',y='total_bill',data=df,col='day',kind='line')
plt.show()

# %%
sns.relplot(x='size',y='total_bill',data=df,col='day',kind='line')
plt.show()
# relational plot

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# <h2>catgorical plot</h2>

# %%
# catgorical plot
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex')
plt.show()

# strip chart

# %%
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex',kind='swarm')
plt.title('swarm chart')
plt.show()

# %%
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex',kind='bar')
plt.title('bar chart')
plt.show()

# %%
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex',kind='violin')
plt.title('violin chart')
plt.show()

# %%
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex',kind='boxen')
plt.show()

# %%
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex',kind='box')
plt.show()

# %%
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex',kind='point')
plt.show()

# %%
sns.catplot(y='total_bill',data=df,hue='sex',kind='count')
plt.show()
## count only pass one parameter

# %%
sns.catplot(x='smoker',data=df,hue='sex',kind='count')
plt.show()

# %% [markdown]
# <h1>Titanic Dataset Perform

# %%
titan=sns.load_dataset('titanic')
titan.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.relplot(x='survived',y='sex',data=titan)
plt.show()

# %%
sns.relplot(x='survived',y='alive',data=titan,hue='sex',style='adult_male',kind='line')
plt.show()

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.relplot(x='sepal_length',y='petal_length',data=iris)
plt.show()

# %%
sns.relplot(x='sepal_length',y='petal_length',data=iris,hue='sepal_width',style='petal_width',kind='line')
plt.show()

# %%
sns.relplot(x='sepal_length',y='petal_length',data=iris,hue='sepal_width',style='petal_width',kind='scatter')
plt.show()

# %%
sns.relplot(x='sepal_length',y='petal_length',data=iris,hue='species',kind='line')
plt.show()

# %%
sns.relplot(x='sepal_length',y='petal_length',data=iris,hue='species',kind='scatter')
plt.show()
